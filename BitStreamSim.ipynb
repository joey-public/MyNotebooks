# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

# %%
Rb = 50      #hz
Nsyms = 5
T = Nsyms / Rb 
fs = 100*Rb

t = np.arange(0,5/Rb,1/fs)
sq_wave = signal.square(2*np.pi*Rb/2*t)
plt.plot(t, sq_wave)

# %%
from my_dsp import my_fft
fftlen = sq_wave.size
f, sq_wave_f = my_fft(sq_wave, fs, fftlen)
f = np.arange(-fs/2, fs/2, fs/fftlen)
plt.plot(f, 20*np.log10(np.abs(sq_wave_f)))
plt.ylim(-10,50)
plt.xlim(-100, 100)
# Out:
# C:\Users\josep\AppData\Local\Temp\ipykernel_27324\4070112548.py:5: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(f, 20*np.log10(np.abs(sq_wave_f)))
# (-100.0, 100.0)

# %%
alphabet = np.array([-1, 1], dtype=complex)
data = np.random.choice(alphabet, (Nsyms,1))
